# %% [markdown]
# # Mount Google Drive

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
RUTA = "/content/drive/MyDrive/Entrega-NLP-Bartolomé_Flores_Vicaria"

# %%
# %cd "$RUTA"
# Out:
# /content/drive/MyDrive/Entrega-NLP-Bartolomé_Flores_Vicaria

# %%
from helper_functions import *
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
path_csv = "results_test.csv"
df = pd.read_csv(path_csv, sep=';', decimal='.',index_col=0)

# %% [markdown]
# # Reporte métricas

# %%
df.head()
# Out:
#                           accuracy  precision    recall        f1
# GradientBoost             0.710101   0.703825  0.710101  0.687459
# DeepLearning              0.677778   0.686943  0.677778  0.681099
# DeepLearningEmbedding     0.637374   0.602473  0.637374  0.532694
# EncoderLSTM               0.634343   0.402392  0.634343  0.492420
# UniversalSentenceEncoder  0.795960   0.793629  0.795960  0.790624

# %%
df.plot()
plt.xticks(rotation=75)
plt.grid(True)
plt.show()

# %% [markdown]
#   La gráfica muestra lo resultados de los algoritmos en diferentes métricas. Respecto al algoritmo que usa Bow el mejor resultado se ha obtenido con el algoritmo de aprendizaje automático GradienBoost. El mejor algoritmo que usa otras técnicas que no son Bow , el mejor resultado se ha obtenido con el Universal Sentence Enconder que es un algoritmo preentrenado de Tensorflow hub.
